# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jaspreet'

# %%
os.chdir('D:/')
import pandas as pd
missing_values = ["n/a", "na", "--"]
df=pd.read_csv('Car_sales.csv',na_values = missing_values)

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0  Acura          Integra                        16.919    16.360
# 1  Acura          TL                             39.384    19.875
# 2  Acura          CL                             14.114    18.225
# 3  Acura          RL                              8.588    29.725
# 4  Audi           A4                             20.397    22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year               36
# Vehicle type            0
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
df['x_4_year'].tail()
# Out:
# 152   NaN
# 153   NaN
# 154   NaN
# 155   NaN
# 156   NaN
# Name: x_4_year, dtype: float64

# %%
df['x_4_year'].fillna(df['x_4_year'].median(),inplace=True)
df['Price in thousands'].fillna(method='ffill',inplace=True)
df['Engine size'].fillna(method='ffill',inplace=True)

# %%
df.tail()
# Out:
#       Manufacturer              Model  Sales in thousands  x_4_year  \
# 152  Volvo          V40                             3.545     14.18
# 153  Volvo          S70                            15.245     14.18
# 154  Volvo          V70                            17.531     14.18
# 155  Volvo          C70                             3.493     14.18
# 156  Volvo          S80                            18.969     14.18
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 152    Passenger                24.4          1.9       160.0      100.5
# 153    Passenger                27.5          2.4       168.0      104.9
# 154    Passenger                28.8          2.4       168.0      104.9
# 155    Passenger                45.5          2.3       236.0      104.9
# 156    Passenger                36.0          2.9       201.0      109.9
#
#      Width  Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year                0
# Vehicle type            0
# Price in thousands      0
# Engine size             0
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
df['Horsepower'].fillna(method='bfill',inplace=True)
df['Wheelbase'].fillna(method='bfill',inplace=True)
df['Width'].fillna(method='bfill',inplace=True)
df['Length'].fillna(method='bfill',inplace=True)
df['Curb weight'].fillna(method='bfill',inplace=True)
df['Fuel capacity'].fillna(method='bfill',inplace=True)
df['Fuel efficiency'].fillna(method='bfill',inplace=True)

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year                0
# Vehicle type            0
# Price in thousands      0
# Engine size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb weight             0
# Fuel capacity           0
# Fuel efficiency         0
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0  Acura          Integra                        16.919    16.360
# 1  Acura          TL                             39.384    19.875
# 2  Acura          CL                             14.114    18.225
# 3  Acura          RL                              8.588    29.725
# 4  Audi           A4                             20.397    22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger               28.40          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year                0
# Vehicle type            0
# Price in thousands      0
# Engine size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb weight             0
# Fuel capacity           0
# Fuel efficiency         0
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
median=df['XX'].median()

# %%
df['XX'].fillna(median,inplace=True)

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# x_4_year                0
# Vehicle type            0
# Price in thousands      0
# Engine size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb weight             0
# Fuel capacity           0
# Fuel efficiency         0
# Latest Launch           0
# Unnamed: 15           157
# XX                      0
# dtype: int64

# %%
df['Latest Launch'].head(10)
# Out:
# 0     2-Feb-14
# 1     6-Mar-15
# 2     1-Apr-14
# 3     3-Oct-15
# 4    10-Aug-15
# 5     8-Sep-15
# 6    27-Feb-14
# 7    28-Jun-15
# 8    29-Jan-14
# 9     4-Apr-15
# Name: Latest Launch, dtype: object

# %%
import seaborn as sns

# %%
sns.distplot(df['XX'])

# %%
df.drop('Unnamed: 15',axis=1,inplace=True)

# %%
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0  Acura          Integra                        16.919    16.360
# 1  Acura          TL                             39.384    19.875
# 2  Acura          CL                             14.114    18.225
# 3  Acura          RL                              8.588    29.725
# 4  Audi           A4                             20.397    22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger               28.40          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch      XX
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.describe()
# Out:
#        Sales in thousands    x_4_year  Price in thousands  Engine size  \
# count          157.000000  157.000000          157.000000   157.000000
# mean            52.998076   17.180318           27.403229     3.063694
# std             68.029422   10.178562           14.259785     1.041889
# min              0.110000    5.160000            9.235000     1.000000
# 25%             14.114000   12.545000           18.145000     2.300000
# 50%             29.450000   14.180000           23.400000     3.000000
# 75%             67.956000   18.140000           31.930000     3.500000
# max            540.561000   67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb weight  \
# count  157.000000  157.000000  157.000000  157.000000   157.000000
# mean   186.375796  107.522293   71.170701  187.410191     3.382191
# std     56.771067    7.629469    3.450553   13.414617     0.627721
# ...
